# %%
import numpy as np
# from keras.datasets import mnist
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import datasets, layers, models

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Lambda, Dropout
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
# (x_train_load, y_train_load), (x_test_load, y_test_load) = datasets.cifar10.load_data()
(x_train_load, y_train_load), (x_test_load, y_test_load) = cifar10.load_data()

# 處理數據
x_train_load = x_train_load[:500]
y_train_load = y_train_load[:500]

x_test_load = x_test_load[:20]
y_test_load = y_test_load[:20]

print(x_test_load.shape)
# Out:
# (20, 32, 32, 3)

# %%
# Data normalization

x_train = x_train_load.reshape((x_train_load.shape[0], 32, 32, 3)).astype('float32') / 255     # ==> 39s
x_test = x_test_load.reshape((x_test_load.shape[0], 32, 32, 3)).astype('float32') / 255
# x_train = x_train_load / 255                       # ==> 37s  43
# x_test = x_test_load/ 255

# 將標籤轉換為 one-hot 編碼
y_train = to_categorical(y_train_load)
y_test = to_categorical(y_test_load)

print(x_train.shape)
# Out:
# (500, 32, 32, 3)

# %%
# 建立模型
import time
start_time = time.time()

model = Sequential()
model.add(Conv2D(8, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(10, activation='softmax'))

# 編譯模型
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 訓練模型
history = model.fit(x_train, y_train, epochs=50, batch_size=64, validation_data=(x_test, y_test))
# history = model.fit(train_generator, epochs=50, batch_size=64, validation_data=(x_test, y_test))
end_time = time.time()
print(f"Training took {end_time - start_time} seconds")
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 92ms/step - loss: 2.3056 - accuracy: 0.1120 - val_loss: 2.2885 - val_accuracy: 0.0500
# Epoch 2/50
# 8/8 [==============================] - 0s 42ms/step - loss: 2.2936 - accuracy: 0.1300 - val_loss: 2.2847 - val_accuracy: 0.1000
# Epoch 3/50
# 8/8 [==============================] - 0s 53ms/step - loss: 2.2876 - accuracy: 0.1300 - val_loss: 2.2901 - val_accuracy: 0.1000
# Epoch 4/50
# 8/8 [==============================] - 1s 61ms/step - loss: 2.2805 - accuracy: 0.1300 - val_loss: 2.2941 - val_accuracy: 0.1000
# Epoch 5/50
# 8/8 [==============================] - 1s 67ms/step - loss: 2.2734 - accuracy: 0.1300 - val_loss: 2.2979 - val_accuracy: 0.1000
# Epoch 6/50
# 8/8 [==============================] - 1s 62ms/step - loss: 2.2609 - accuracy: 0.1300 - val_loss: 2.2937 - val_accuracy: 0.1000
# Epoch 7/50
# 8/8 [==============================] - 0s 46ms/step - loss: 2.2446 - accuracy: 0.1320 - val_loss: 2.2779 - val_accuracy: 0.1000
# Epoch 8/50
# 8/8 [==============================] - 0s 41ms/step - loss: 2.2195 - accuracy: 0.1300 - val_loss: 2.2304 - val_accuracy: 0.0500
# Epoch 9/50
# 8/8 [==============================] - 0s 41ms/step - loss: 2.1715 - accuracy: 0.2000 - val_loss: 2.2150 - val_accuracy: 0.0500
# Epoch 10/50
# 8/8 [==============================] - 0s 46ms/step - loss: 2.1191 - accuracy: 0.2540 - val_loss: 2.2485 - val_accuracy: 0.0500
# Epoch 11/50
# 8/8 [==============================] - 0s 49ms/step - loss: 2.0780 - accuracy: 0.2500 - val_loss: 2.1106 - val_accuracy: 0.2000
# Epoch 12/50
# 8/8 [==============================] - 0s 44ms/step - loss: 2.0082 - accuracy: 0.2960 - val_loss: 2.0306 - val_accuracy: 0.2500
# Epoch 13/50
# 8/8 [==============================] - 0s 55ms/step - loss: 1.9571 - accuracy: 0.3220 - val_loss: 2.0739 - val_accuracy: 0.1500
# Epoch 14/50
# 8/8 [==============================] - 0s 43ms/step - loss: 1.9143 - accuracy: 0.3360 - val_loss: 1.9061 - val_accuracy: 0.3500
# Epoch 15/50
# 8/8 [==============================] - 0s 46ms/step - loss: 1.8969 - accuracy: 0.3400 - val_loss: 1.9808 - val_accuracy: 0.1000
# Epoch 16/50
# 8/8 [==============================] - 0s 44ms/step - loss: 1.8522 - accuracy: 0.3460 - val_loss: 1.8432 - val_accuracy: 0.2500
# Epoch 17/50
# 8/8 [==============================] - 0s 25ms/step - loss: 1.8011 - accuracy: 0.3700 - val_loss: 1.9446 - val_accuracy: 0.2000
# Epoch 18/50
# 8/8 [==============================] - 0s 18ms/step - loss: 1.7824 - accuracy: 0.3600 - val_loss: 1.8438 - val_accuracy: 0.3500
# Epoch 19/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.7444 - accuracy: 0.3880 - val_loss: 1.8841 - val_accuracy: 0.2500
# Epoch 20/50
# 8/8 [==============================] - 0s 16ms/step - loss: 1.7342 - accuracy: 0.3800 - val_loss: 1.8876 - val_accuracy: 0.4000
# Epoch 21/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.7259 - accuracy: 0.3940 - val_loss: 1.9454 - val_accuracy: 0.3500
# Epoch 22/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.6881 - accuracy: 0.4040 - val_loss: 1.8658 - val_accuracy: 0.4000
# Epoch 23/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.6520 - accuracy: 0.4180 - val_loss: 1.8136 - val_accuracy: 0.3500
# Epoch 24/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.6443 - accuracy: 0.4200 - val_loss: 1.8903 - val_accuracy: 0.3500
# Epoch 25/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.6047 - accuracy: 0.4500 - val_loss: 1.9207 - val_accuracy: 0.3000
# Epoch 26/50
# 8/8 [==============================] - 0s 27ms/step - loss: 1.6120 - accuracy: 0.4320 - val_loss: 1.7726 - val_accuracy: 0.4500
# Epoch 27/50
# 8/8 [==============================] - 0s 14ms/step - loss: 1.5975 - accuracy: 0.4580 - val_loss: 1.8057 - val_accuracy: 0.3500
# Epoch 28/50
# 8/8 [==============================] - 0s 38ms/step - loss: 1.5538 - accuracy: 0.4260 - val_loss: 1.8002 - val_accuracy: 0.4000
# Epoch 29/50
# 8/8 [==============================] - 0s 39ms/step - loss: 1.5210 - accuracy: 0.4640 - val_loss: 1.9507 - val_accuracy: 0.2000
# Epoch 30/50
# 8/8 [==============================] - 0s 57ms/step - loss: 1.4979 - accuracy: 0.4840 - val_loss: 1.7603 - val_accuracy: 0.4000
# Epoch 31/50
# 8/8 [==============================] - 0s 52ms/step - loss: 1.4619 - accuracy: 0.5040 - val_loss: 1.9165 - val_accuracy: 0.3000
# Epoch 32/50
# 8/8 [==============================] - 0s 42ms/step - loss: 1.4594 - accuracy: 0.4960 - val_loss: 1.8576 - val_accuracy: 0.3000
# Epoch 33/50
# 8/8 [==============================] - 0s 48ms/step - loss: 1.4779 - accuracy: 0.4900 - val_loss: 1.7813 - val_accuracy: 0.4000
# Epoch 34/50
# 8/8 [==============================] - 0s 45ms/step - loss: 1.4108 - accuracy: 0.4960 - val_loss: 1.7487 - val_accuracy: 0.4500
# Epoch 35/50
# 8/8 [==============================] - 0s 49ms/step - loss: 1.3952 - accuracy: 0.5360 - val_loss: 1.8033 - val_accuracy: 0.2500
# Epoch 36/50
# 8/8 [==============================] - 0s 41ms/step - loss: 1.3564 - accuracy: 0.5440 - val_loss: 1.7529 - val_accuracy: 0.4000
# Epoch 37/50
# 8/8 [==============================] - 0s 50ms/step - loss: 1.3530 - accuracy: 0.5420 - val_loss: 1.7317 - val_accuracy: 0.4000
# Epoch 38/50
# 8/8 [==============================] - 0s 48ms/step - loss: 1.3160 - accuracy: 0.5520 - val_loss: 1.8493 - val_accuracy: 0.3000
# Epoch 39/50
# 8/8 [==============================] - 0s 43ms/step - loss: 1.3155 - accuracy: 0.5520 - val_loss: 1.8372 - val_accuracy: 0.2500
# Epoch 40/50
# 8/8 [==============================] - 0s 48ms/step - loss: 1.2936 - accuracy: 0.5640 - val_loss: 1.8250 - val_accuracy: 0.4000
# Epoch 41/50
# 8/8 [==============================] - 0s 43ms/step - loss: 1.2875 - accuracy: 0.5700 - val_loss: 1.8184 - val_accuracy: 0.3000
# Epoch 42/50
# 8/8 [==============================] - 0s 43ms/step - loss: 1.2711 - accuracy: 0.5780 - val_loss: 1.8300 - val_accuracy: 0.4000
# Epoch 43/50
# 8/8 [==============================] - 0s 42ms/step - loss: 1.2529 - accuracy: 0.5760 - val_loss: 1.9548 - val_accuracy: 0.2000
# Epoch 44/50
# 8/8 [==============================] - 0s 23ms/step - loss: 1.1997 - accuracy: 0.6060 - val_loss: 1.7507 - val_accuracy: 0.4000
# Epoch 45/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.2111 - accuracy: 0.5800 - val_loss: 1.9323 - val_accuracy: 0.2000
# Epoch 46/50
# 8/8 [==============================] - 0s 23ms/step - loss: 1.1845 - accuracy: 0.6040 - val_loss: 1.8371 - val_accuracy: 0.3000
# Epoch 47/50
# 8/8 [==============================] - 0s 13ms/step - loss: 1.1732 - accuracy: 0.6020 - val_loss: 1.7754 - val_accuracy: 0.3500
# Epoch 48/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.1593 - accuracy: 0.5940 - val_loss: 1.7428 - val_accuracy: 0.3500
# Epoch 49/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.1543 - accuracy: 0.6060 - val_loss: 1.9143 - val_accuracy: 0.2500
# Epoch 50/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.1104 - accuracy: 0.6320 - val_loss: 1.8148 - val_accuracy: 0.3500
# Training took 15.654788970947266 seconds

# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
train_datagen = ImageDataGenerator(rotation_range=0,zoom_range=0.1,width_shift_range=0.1,height_shift_range=0.1)
train_generator = train_datagen.flow(x_train,y_train,batch_size=32,shuffle=True) 
import time
start_time = time.time()
model = Sequential()
model.add(Conv2D(8, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(10, activation='softmax'))
# 編譯模型
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 訓練模型
# history = model.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test))
history = model.fit(train_generator, epochs=50, batch_size=64, validation_data=(x_test, y_test))
end_time = time.time()
print(f"Training took {end_time - start_time} seconds")
# Out:
# Epoch 1/50
# 16/16 [==============================] - 2s 78ms/step - loss: 2.3004 - accuracy: 0.0960 - val_loss: 2.3097 - val_accuracy: 0.1500
# Epoch 2/50
# 16/16 [==============================] - 1s 56ms/step - loss: 2.2858 - accuracy: 0.1180 - val_loss: 2.2897 - val_accuracy: 0.1000
# Epoch 3/50
# 16/16 [==============================] - 1s 57ms/step - loss: 2.2738 - accuracy: 0.1280 - val_loss: 2.2552 - val_accuracy: 0.2500
# Epoch 4/50
# 16/16 [==============================] - 1s 42ms/step - loss: 2.2461 - accuracy: 0.1740 - val_loss: 2.1178 - val_accuracy: 0.3500
# Epoch 5/50
# 16/16 [==============================] - 1s 59ms/step - loss: 2.2121 - accuracy: 0.1700 - val_loss: 2.0633 - val_accuracy: 0.2500
# Epoch 6/50
# 16/16 [==============================] - 1s 50ms/step - loss: 2.1763 - accuracy: 0.1680 - val_loss: 2.0017 - val_accuracy: 0.2000
# Epoch 7/50
# 16/16 [==============================] - 1s 58ms/step - loss: 2.1539 - accuracy: 0.1640 - val_loss: 1.9219 - val_accuracy: 0.3000
# Epoch 8/50
# 16/16 [==============================] - 1s 50ms/step - loss: 2.1258 - accuracy: 0.2160 - val_loss: 1.9319 - val_accuracy: 0.2000
# Epoch 9/50
# 16/16 [==============================] - 1s 53ms/step - loss: 2.1031 - accuracy: 0.1860 - val_loss: 1.8929 - val_accuracy: 0.4000
# Epoch 10/50
# 16/16 [==============================] - 1s 57ms/step - loss: 2.0817 - accuracy: 0.2220 - val_loss: 1.7984 - val_accuracy: 0.3500
# Epoch 11/50
# 16/16 [==============================] - 1s 51ms/step - loss: 2.0561 - accuracy: 0.2580 - val_loss: 1.8282 - val_accuracy: 0.3500
# Epoch 12/50
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0322 - accuracy: 0.2500 - val_loss: 1.7880 - val_accuracy: 0.3000
# Epoch 13/50
# 16/16 [==============================] - 1s 46ms/step - loss: 1.9966 - accuracy: 0.2980 - val_loss: 1.8164 - val_accuracy: 0.3000
# Epoch 14/50
# 16/16 [==============================] - 1s 55ms/step - loss: 1.9965 - accuracy: 0.2900 - val_loss: 1.8180 - val_accuracy: 0.3000
# Epoch 15/50
# 16/16 [==============================] - 1s 65ms/step - loss: 2.0153 - accuracy: 0.2760 - val_loss: 1.9033 - val_accuracy: 0.2000
# Epoch 16/50
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9575 - accuracy: 0.2920 - val_loss: 1.7474 - val_accuracy: 0.4000
# Epoch 17/50
# 16/16 [==============================] - 1s 61ms/step - loss: 1.9403 - accuracy: 0.3040 - val_loss: 1.8105 - val_accuracy: 0.2500
# Epoch 18/50
# 16/16 [==============================] - 1s 56ms/step - loss: 1.9340 - accuracy: 0.2760 - val_loss: 1.8568 - val_accuracy: 0.3000
# Epoch 19/50
# 16/16 [==============================] - 1s 54ms/step - loss: 1.9102 - accuracy: 0.2980 - val_loss: 1.9053 - val_accuracy: 0.2500
# Epoch 20/50
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9233 - accuracy: 0.2920 - val_loss: 1.7173 - val_accuracy: 0.3500
# Epoch 21/50
# 16/16 [==============================] - 1s 55ms/step - loss: 1.9011 - accuracy: 0.2980 - val_loss: 1.8009 - val_accuracy: 0.3000
# Epoch 22/50
# 16/16 [==============================] - 1s 45ms/step - loss: 1.8330 - accuracy: 0.3440 - val_loss: 1.8012 - val_accuracy: 0.4000
# Epoch 23/50
# 16/16 [==============================] - 1s 54ms/step - loss: 1.8876 - accuracy: 0.3060 - val_loss: 2.1028 - val_accuracy: 0.2500
# Epoch 24/50
# 16/16 [==============================] - 1s 66ms/step - loss: 1.9575 - accuracy: 0.2960 - val_loss: 1.8477 - val_accuracy: 0.3000
# Epoch 25/50
# 16/16 [==============================] - 1s 56ms/step - loss: 1.8656 - accuracy: 0.3380 - val_loss: 1.7358 - val_accuracy: 0.3500
# Epoch 26/50
# 16/16 [==============================] - 1s 52ms/step - loss: 1.8390 - accuracy: 0.3280 - val_loss: 1.7313 - val_accuracy: 0.4000
# Epoch 27/50
# 16/16 [==============================] - 1s 62ms/step - loss: 1.7920 - accuracy: 0.3820 - val_loss: 1.8116 - val_accuracy: 0.2500
# Epoch 28/50
# 16/16 [==============================] - 1s 49ms/step - loss: 1.8171 - accuracy: 0.3600 - val_loss: 1.6804 - val_accuracy: 0.5000
# Epoch 29/50
# 16/16 [==============================] - 1s 50ms/step - loss: 1.7736 - accuracy: 0.3800 - val_loss: 1.8236 - val_accuracy: 0.3000
# Epoch 30/50
# 16/16 [==============================] - 1s 51ms/step - loss: 1.7737 - accuracy: 0.3620 - val_loss: 1.7579 - val_accuracy: 0.2500
# Epoch 31/50
# 16/16 [==============================] - 1s 62ms/step - loss: 1.7323 - accuracy: 0.3800 - val_loss: 1.6794 - val_accuracy: 0.4500
# Epoch 32/50
# 16/16 [==============================] - 1s 53ms/step - loss: 1.6954 - accuracy: 0.3980 - val_loss: 1.7761 - val_accuracy: 0.3500
# Epoch 33/50
# 16/16 [==============================] - 1s 47ms/step - loss: 1.6945 - accuracy: 0.3780 - val_loss: 1.7331 - val_accuracy: 0.3500
# Epoch 34/50
# 16/16 [==============================] - 1s 59ms/step - loss: 1.6525 - accuracy: 0.4120 - val_loss: 1.7618 - val_accuracy: 0.4000
# Epoch 35/50
# 16/16 [==============================] - 1s 48ms/step - loss: 1.6753 - accuracy: 0.3880 - val_loss: 1.6289 - val_accuracy: 0.5000
# Epoch 36/50
# 16/16 [==============================] - 1s 50ms/step - loss: 1.6356 - accuracy: 0.4300 - val_loss: 1.6830 - val_accuracy: 0.3000
# Epoch 37/50
# 16/16 [==============================] - 1s 55ms/step - loss: 1.6468 - accuracy: 0.4140 - val_loss: 1.8243 - val_accuracy: 0.4000
# Epoch 38/50
# 16/16 [==============================] - 1s 40ms/step - loss: 1.6660 - accuracy: 0.4320 - val_loss: 1.5556 - val_accuracy: 0.4000
# Epoch 39/50
# 16/16 [==============================] - 1s 66ms/step - loss: 1.6797 - accuracy: 0.4160 - val_loss: 1.6455 - val_accuracy: 0.3500
# Epoch 40/50
# 16/16 [==============================] - 1s 56ms/step - loss: 1.5969 - accuracy: 0.4560 - val_loss: 1.6622 - val_accuracy: 0.2500
# Epoch 41/50
# 16/16 [==============================] - 1s 54ms/step - loss: 1.5812 - accuracy: 0.4340 - val_loss: 1.5753 - val_accuracy: 0.5000
# Epoch 42/50
# 16/16 [==============================] - 1s 59ms/step - loss: 1.5836 - accuracy: 0.4440 - val_loss: 1.6116 - val_accuracy: 0.3000
# Epoch 43/50
# 16/16 [==============================] - 1s 52ms/step - loss: 1.6069 - accuracy: 0.4280 - val_loss: 1.5862 - val_accuracy: 0.3500
# Epoch 44/50
# 16/16 [==============================] - 1s 48ms/step - loss: 1.5925 - accuracy: 0.4060 - val_loss: 1.7963 - val_accuracy: 0.2000
# Epoch 45/50
# 16/16 [==============================] - 1s 50ms/step - loss: 1.5851 - accuracy: 0.4440 - val_loss: 1.4498 - val_accuracy: 0.5500
# Epoch 46/50
# 16/16 [==============================] - 1s 52ms/step - loss: 1.5549 - accuracy: 0.4640 - val_loss: 1.6486 - val_accuracy: 0.4000
# Epoch 47/50
# 16/16 [==============================] - 1s 67ms/step - loss: 1.5685 - accuracy: 0.4480 - val_loss: 1.4231 - val_accuracy: 0.5500
# Epoch 48/50
# 16/16 [==============================] - 1s 53ms/step - loss: 1.5417 - accuracy: 0.4380 - val_loss: 1.4800 - val_accuracy: 0.5500
# Epoch 49/50
# 16/16 [==============================] - 1s 51ms/step - loss: 1.5478 - accuracy: 0.4500 - val_loss: 1.6656 - val_accuracy: 0.3500
# Epoch 50/50
# 16/16 [==============================] - 1s 62ms/step - loss: 1.5472 - accuracy: 0.4500 - val_loss: 1.5936 - val_accuracy: 0.2500
# Training took 46.0965895652771 seconds

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(x_train)
y_pred_label = np.argmax(y_pred, axis=1)
y_train_label = np.argmax(y_train, axis=1)
cm = confusion_matrix(y_train_label, y_pred_label)

# 打印混淆矩陣
print("Confusion Matrix:")
print(cm)
# Out:
# 16/16 [==============================] - 0s 2ms/step
# Confusion Matrix:
# [[ 8 11  1  1  0  1  0  6 17  6]
#  [ 0 52  0  0  1  1  1  0  4  6]
#  [ 2  4 12  2  7  2  5  4  1  4]
#  [ 1  5  0 12  1  3  8  7  0 10]
#  [ 1  3  4  0 13  1 16 10  1  1]
#  [ 0  3  4  2  2 14  6  7  0  2]
#  [ 0  0  0  1  2  0 44  2  0  4]
#  [ 0  4  0  0  3  1  1 33  2  6]
#  [ 1 10  0  0  0  0  0  2 25  7]
#  [ 0  6  0  0  0  0  1  3  1 45]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 繪製混淆矩陣的熱圖
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Exercise : try to encapsulate the confusion matrix functionality and utilize it to present the results of both training set and testing set

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], 'r', label='Training loss')
plt.plot(history.history['val_loss'], 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# 評估模型
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8148 - accuracy: 0.3500
# Test accuracy: 0.3499999940395355

# %%
y_pred = model.predict(x_test)
print(y_pred.shape)

# print(|y_pred)
y_pred_label = np.argmax(y_pred, axis=1)    
print('y_pred: ', y_pred_label)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# (20, 10)
# y_pred:  [6 8 1 8 4 3 5 6 4 9 0 9 7 1 1 8 5 4 8 7]

# %%
# 找出預測錯誤的索引
y_pred = model.predict(x_test)
print('y_shape: ', y_pred.shape)

y_pred_label = np.argmax(y_pred, axis=1)  # axis=1：沿著行查找每行的最大值的索引。axis=0：沿著列查找每列的最大值的索引。
y_test_label = np.argmax(y_test, axis=1)

print('y_pred: ', y_pred_label)
print('y_test: ', y_test_label)

len(x_test)
errors = np.where(y_pred_label != y_test_label)[0]
print(f'Index of Prediction errors:  {errors} ')
print(f'Total number of prediction errors: {len(errors)}')
# Out:
# 1/1 [==============================] - 0s 19ms/step
# y_shape:  (20, 10)
# y_pred:  [6 8 1 8 4 3 5 6 4 9 0 9 7 1 1 8 5 4 8 7]
# y_test:  [3 8 8 0 6 6 1 6 3 1 0 9 5 7 9 8 5 7 8 6]
# Index of Prediction errors:  [ 0  2  3  4  5  6  8  9 12 13 14 17 19]
# Total number of prediction errors: 13

# %%
# 假設 num_images 是你的圖像數量
num_images = len(errors)  # 或其他你定義的圖像數量

# 決定每排最多顯示的圖像數
images_per_row = num_images // 2 + num_images % 2

# 創建子圖，自動計算需要的行數
rows = (num_images + images_per_row - 1) // images_per_row
fig, axes = plt.subplots(rows, images_per_row, figsize=(10, 4))
axes = axes.flatten()  # 使 axes 可迭代，保證即使是一行也能正常工作

# 顯示圖像
for i, ax in enumerate(axes):
    if i < num_images:
        ax.imshow(x_test_load[errors[i]])
        ax.set_title(f'Label: {y_pred_label[errors[i]]}')
        ax.axis('off')  # 不顯示軸
    else:
        ax.axis('off')  # 對於不需要的軸也關閉顯示

plt.tight_layout()
plt.show()
